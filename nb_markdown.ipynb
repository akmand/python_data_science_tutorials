# %% [markdown]
# # NOTEBOOK MARKDOWN TUTORIAL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Table of Contents
# - [Plotting Prep](#pp)
# - [Plotting Sine Function](#sine)
# - [Working with Markdown](#md)

# %% [markdown]
# ## Prep for Plotting <a></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:229: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## How to Plot the Sine Function <a></a>

# %%
x = np.arange(0, 4*np.pi, 0.1)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.title('sine of x')
plt.show()

# %% [markdown]
# ## Working with Markdown Commands <a></a>

# %% [markdown]
# ### Header 3

# %% [markdown]
# &gt; This is a blockquote

# %% [markdown]
# ---

# %% [markdown]
# This is code section example:
# ```Python
# a = 23
# b = 15
# print(a+b)
# ```

# %% [markdown]
# Here is a line break <br> that looks nice.

# %% [markdown]
# Everybody likes `machine learning`.

# %% [markdown]
# This is *italic*.

# %% [markdown]
# This is **bold**.

# %% [markdown]
# Here is an unordered list:
# - Item 1
# - Item 2
# - Item 3

# %% [markdown]
# Here is an ordered list:
# 1. Item 1
# 2. Item 2
# 3. Item 3

# %% [markdown]
# How to create a table:
#
# |Course Name | Code | Level|
# |-------|-------|------|
# |Machine Learning | 2319 | PG |
# |Intro to Analytics | 2350 | UG |

# %% [markdown]
# This is a famous formula: $E=mc^2$

# %% [markdown]
# Here is a centered math formula: $$\sum_i^{j+k} x^3= \frac{\alpha}{\beta}$$

# %% [markdown]
# External link to our website is [here](http://featureranking.com).

# %% [markdown]
# ---
# www.featureranking.com
