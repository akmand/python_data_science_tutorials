# %% [markdown]
# # NOTEBOOK MARKDOWN TUTORIAL

# %% [markdown]
# # Table of Contents
# - [Working with Images](#img)
# - [Plotting Prep](#pp)
# - [Plotting Sine Function](#sine)
# - [Working with Markdown](#md)

# %% [markdown]
# ## Working with Images <a id='img'></a>

# %% [markdown]
# ### Linking an Image
#
# How to **_LINK_** an image, resize, and align within a **markdown** cell (suppose the name of the image file is "Banner_MATH2319.png" in the same directory as in this Jupyter notebook):
# ```HTML
# <img src="./Banner_MATH2319.png" width=400 align="left"/>
# ```

# %% [markdown]
# <img src="Banner_MATH2319.png" width=400 align="left"/>

# %% [markdown]
# ### Inserting an Image
#
# How to **_INSERT_** an image within a **markdown** cell (suppose the name of the image file is "Banner_MATH2319.png" in the same directory as in this Jupyter notebook):
# ```HTML
# ![Banner_MATH2319.png](attachment:Banner_MATH2319.png)
# ```
# Alternatively, within Jupyter Notebook environment, **go to Edit menu option and then choose "Insert Image".**
#
# For the actual embedding to take place, you will also need to **run** your markdown cell!
#
# ### The Difference
#
# When an image is **linked**, the image just displays within your notebook but does not become a part of your notebook. This keeps the notebook size small. This is the preferred option when you would like to share your notebook in PDF or HTML format.
#
# When an image is **inserted** (that is, embedded), the image becomes part of your notebook. Consequently, notebook size becomes larger. However, this is the preferred option when you would like to share your notebook in Jupyter Notebook format.

# %% [markdown]
# ![Banner_MATH2319.png](attachment:Banner_MATH2319.png)

# %% [markdown]
# ## Prep for Plotting <a id='pp'></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.style.use('seaborn')
# Out:
# C:\Users\akman\AppData\Local\Temp\ipykernel_10476\1566786336.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# ## How to Plot the Sine Function <a id='sine'></a>

# %%
x = np.arange(0, 4*np.pi, 0.1)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.title('sine of x')
plt.show()

# %% [markdown]
# ## Working with Markdown Commands <a id='md'></a>

# %% [markdown]
# ### Header 3

# %% [markdown]
# > This is a block quote.

# %% [markdown]
# This is a line break:
#
# ---

# %% [markdown]
# This is code section example:
# ```Python
# a = 23
# b = 15
# print(a+b)
# ```

# %% [markdown]
# Here is a line break <br>
# that looks nice.

# %% [markdown]
# Emphasis: Everybody likes `machine learning`.

# %% [markdown]
# This is _italic_.

# %% [markdown]
# This is **bold**.

# %% [markdown]
# This is **_bold and italic_**.

# %% [markdown]
# Here is an unordered list using "-" prefix for each list item:
# - Item 1
# - Item 2
# - Item 3

# %% [markdown]
# Here is an ordered list - pay attention that we use the prefix "1." for each list item so that the actual numbering is done automatically for us upon running this markdown cell:
# 1. Item 1
# 1. Item 2
# 1. Item 3

# %% [markdown]
# Here is an ordered list with sublists using tabs:
# 1. Item 1
#     - Item 1A
#     - Item 1B
#         1. Item 1B.1
#         1. Item 1B.2
#     - Item 1C
#     - Item 1D
# 1. Item 2
# 1. Item 3

# %% [markdown]
# How to create a table:
#
# **Raw code:**
# ```HTML
# |Course Name | Code | Level|
# |---|---|---|
# |Machine Learning | 2319 | PG |
# |Intro to Analytics | 2350 | UG |
# ```
#
# **Upon running the cell:**
#
# |Course Name | Code | Level|
# |---|---|---|
# |Machine Learning | 2319 | PG |
# |Intro to Analytics | 2350 | UG |

# %% [markdown]
# This is a famous formula: $E=mc^2$

# %% [markdown]
# Here is a centered math formula: $$\sum_i^{j+k} x^3= \frac{\alpha}{\beta}$$

# %% [markdown]
# External webpage links: Our website is [here](http://www.featureranking.com).

# %% [markdown]
# ---
# www.featureranking.com
